# %%
import requests 

r = requests.get('https://api.github.com/events')

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sun, 23 Apr 2023 05:32:54 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"088fb60779a5ddda9be9c1a9bc848590b0aa6f7f173b8f2f1dc80784358c24ef"', 'Last-Modified': 'Sun, 23 Apr 2023 05:27:54 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000
# ...

# %%
r.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '[{"id":"28598409518","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":581172209,"name":"KntMods/KntMods","url":"https://api.github.com/repos/KntMods/KntMods"},"payload":{"repository_id":581172209,"push_id":13393925385,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"bd0cbf754987ef4daf03452d2cec42f04544c152","before":"c3e5b7168be55ecd18885f94a833294173cd21a7","commits":[{"sha":"bd0cbf754987ef4daf03452d2cec42f04544c152","author":{"email":"41898282+github-actions[bot]@users.noreply.github.com","name":"readme-bot"},"message":"⚡ Update README with the recent activity","distinct":true,"url":"https://api.github.com/repos/KntMods/KntMods/commits/bd0cbf754987ef4daf03452d2cec42f04544c152"}]},"public":true,"created_at":"2023-04-23T05:27:54Z"},{"id":"28598409521","type":"WatchEve
# ...

# %% [markdown]
# #### remember:- we can only get the json response from the server side, if they provide the data in the json format otherwise we will get a error

# %%
r.json()
# Out:
# [{'id': '28598409518',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 581172209,
#    'name': 'KntMods/KntMods',
#    'url': 'https://api.github.com/repos/KntMods/KntMods'},
#   'payload': {'repository_id': 581172209,
#    'push_id': 13393925385,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bd0cbf754987ef4daf03452d2cec42f04544c152',
#    'before': 'c3e5b7168be55ecd18885f94a833294173cd21a7',
#    'commits': [{'sha': 'bd0cbf754987ef4daf03452d2cec42f04544c152',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': '⚡ Update README with the recent activity',
#      'distinct': True,
# ...
